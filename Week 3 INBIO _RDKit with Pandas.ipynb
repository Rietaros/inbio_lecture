# %%
#Import Library , tahap awal untuk menggunakan fungsi dalam rdkit dan PyFingerprint

from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole #Needed to show molecules
from rdkit.Chem.Draw.MolDrawing import MolDrawing, DrawingOptions #Only needed if modifying defaults


from rdkit.Chem import Descriptors
from rdkit.Chem import AllChem
from rdkit import DataStructs
import numpy as np

import pandas as pd

# %%
#read data csv
data = pd.read_csv("test_smiles.csv")
data.head()
# Out:
#                                               smiles    code  chembl_code
# 0  CCCC[C@H](CN(O)C=O)C(=O)N[C@H](C(=O)N1CCN(C)CC...  148147  CHEMBL90756
# 1               ONC(=O)CC3Sc1ccccc1N(CCC2CCCCC2)C3=O   50756  CHEMBL35042
# 2      ONC(=O)CC3Sc1ccccc1N(CC(=O)Nc2cc(F)ccc2F)C3=O   50280  CHEMBL34553
# 3         COc2cccc(C(NCc1cccc(C(F)(F)F)c1)C(=O)NO)c2   38480  CHEMBL29911
# 4                CC(C)CCN1C(=O)C(CC(=O)NO)Cc2ccccc12   51102  CHEMBL34426

# %%
#import pandas tool
from rdkit.Chem import PandasTools
from IPython.display import Image, HTML

pd.set_option('display.max_colwidth', -1)

# %%
PandasTools.AddMoleculeColumnToFrame(data,'smiles','molecule')
data.head()
# Out:
#                                               smiles    code  chembl_code  \
# 0  CCCC[C@H](CN(O)C=O)C(=O)N[C@H](C(=O)N1CCN(C)CC...  148147  CHEMBL90756
# 1               ONC(=O)CC3Sc1ccccc1N(CCC2CCCCC2)C3=O   50756  CHEMBL35042
# 2      ONC(=O)CC3Sc1ccccc1N(CC(=O)Nc2cc(F)ccc2F)C3=O   50280  CHEMBL34553
# 3         COc2cccc(C(NCc1cccc(C(F)(F)F)c1)C(=O)NO)c2   38480  CHEMBL29911
# 4                CC(C)CCN1C(=O)C(CC(=O)NO)Cc2ccccc12   51102  CHEMBL34426
#
#                                             molecule
# 0  <img src="......
# 1  <img src="......
# 2  <img src="......
# 3  <img src="......
# 4  <img src="......

# %%
html_ver = HTML(data.to_html(escape=False))
html_ver
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>smiles</th>
#       <th>code</th>
#       <th>chembl_code</th>
#       <th>molecule</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CCCC[C@H](CN(O)C=O)C(=O)N[C@H](C(=O)N1CCN(C)CC1)C(C)(C)C</td>
#       <td>148147</td>
#       <td>CHEMBL90756</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ONC(=O)CC3Sc1ccccc1N(CCC2CCCCC2)C3=O</td>
#       <td>50756</td>
#       <td>CHEMBL35042</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ONC(=O)CC3Sc1ccccc1N(CC(=O)Nc2cc(F)ccc2F)C3=O</td>
#       <td>50280</td>
#       <td>CHEMBL34553</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>COc2cccc(C(NCc1cccc(C(F)(F)F)c1)C(=O)NO)c2</td>
#       <td>38480</td>
#       <td>CHEMBL29911</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>CC(C)CCN1C(=O)C(CC(=O)NO)Cc2ccccc12</td>
#       <td>51102</td>
#       <td>CHEMBL34426</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>CCCCC(CC(=O)NO)S(=O)c2ccc1ccccc1c2</td>
#       <td>121509</td>
#       <td>CHEMBL77577</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>ON(C[C@@H](Cc1ccccc1)C(=O)N2CCC[C@H]2c4nc3ccccc3[nH]4)C=O</td>
#       <td>473485</td>
#       <td>CHEMBL481391</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>ONC(=O)CN3Cc1c(Br)cccc1N(CC2CC2)S3(=O)=O</td>
#       <td>82927</td>
#       <td>CHEMBL54449</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>ONC(=O)CC2Cc1ccccc1NC2=O</td>
#       <td>51057</td>
#       <td>CHEMBL37522</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>CCCC[C@H](CN(O)C=O)C(=O)N2Cc1ccccc1CC2C(=O)N(C)C</td>
#       <td>148705</td>
#       <td>CHEMBL92044</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>ONCC(=O)Cc1c[nH]c2ccc(Cl)cc12</td>
#       <td>365421</td>
#       <td>CHEMBL373863</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>CCCC[C@H](CN(O)C=O)C(=O)N[C@H](C(=O)N(CCc1ccccc1)Cc2ccccc2)C(C)(C)C</td>
#       <td>148269</td>
#       <td>CHEMBL93532</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#     </tr>
#   </tbody>
# </table>

# %%
#save to excel with embedded image
PandasTools.SaveXlsxFromFrame(data, "data_output.xlsx", molCol='molecule', size=(300, 300))
